# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
matrix = pd.read_csv('../../Pipeline/MultiClass/Family/matrix.txt',sep = '\s+',header=None)

# %%
df2 = matrix.div(matrix.sum(axis=1),axis=0)

# %%
fig, ax = plt.subplots(figsize= (18,16))
sns.heatmap(df2,xticklabels=False,yticklabels=False)

# %%
precision = pd.read_csv("../../Pipeline/MultiClass/Family/precision_by_label.txt",sep=" = ",names=['family_id','precision'])
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
precision
# Out:
#      family_id  precision
# 0          0.0   0.000000
# 1          1.0   0.435310
# 2          2.0   0.700692
# 3          3.0   0.000000
# 4          4.0   0.000000
# 5          5.0   0.000000
# 6          6.0   0.750000
# 7          7.0   0.000000
# 8          8.0   0.272727
# 9          9.0   0.500000
# 10        10.0   0.666667
# 11        11.0   0.368421
# 12        12.0   0.000000
# 13        13.0   0.307034
# 14        14.0   0.000000
# 15        15.0   0.263254
# 16        16.0   0.174532
# 17        17.0   0.001096
# 18        18.0   0.750131
# 19        19.0   0.000000
# 20        20.0   0.059406
# 21        21.0   0.266055
# 22        22.0   0.335025
# 23        23.0   0.166667
# 24        24.0   0.000000
# 25        25.0   0.176087
# 26        26.0   0.000000
# 27        27.0   0.000000
# 28        28.0   0.060606
# 29        29.0   0.270080
# ..         ...        ...
# 781      781.0   0.717791
# 782      782.0   0.008658
# 783      783.0   0.000000
# ...

# %%
family = pd.read_csv("../../Pipeline/MultiClass/all.vect.family.index", sep=" ",names = ['family','real_tax_id'])

# %%
family
# Out:
#      family  real_tax_id
# 0         0         5809
# 1         1        31469
# 2         2         5654
# 3         3         3216
# 4         4         3401
# 5         5         3440
# 6         6         4405
# 7         7        41773
# 8         8        25664
# 9         9         3298
# 10       10         4410
# 11       11         3362
# 12       12         3394
# 13       13         3367
# 14       14        25623
# 15       15         3700
# 16       16         3931
# 17       17         3629
# 18       18         3803
# 19       19         3977
# 20       20         3688
# 21       21        22973
# 22       22         3745
# 23       23         3568
# 24       24         3563
# 25       25         4070
# 26       26         4118
# 27       27         4335
# 28       28         4056
# 29       29         4210
# ..      ...          ...
# 781     781       548682
# 782     782        90627
# 783     783       206349
# 784     784          481
# 785     785       171551
# ...

# %%
new_family = precision.join(family)

# %%
new_family
# Out:
#      family_id  precision  family  real_tax_id
# 0          0.0   0.000000       0         5809
# 1          1.0   0.435310       1        31469
# 2          2.0   0.700692       2         5654
# 3          3.0   0.000000       3         3216
# 4          4.0   0.000000       4         3401
# 5          5.0   0.000000       5         3440
# 6          6.0   0.750000       6         4405
# 7          7.0   0.000000       7        41773
# 8          8.0   0.272727       8        25664
# 9          9.0   0.500000       9         3298
# 10        10.0   0.666667      10         4410
# 11        11.0   0.368421      11         3362
# 12        12.0   0.000000      12         3394
# 13        13.0   0.307034      13         3367
# 14        14.0   0.000000      14        25623
# 15        15.0   0.263254      15         3700
# 16        16.0   0.174532      16         3931
# 17        17.0   0.001096      17         3629
# 18        18.0   0.750131      18         3803
# ...

# %%
group = pd.read_csv("../../Pipeline/MultiClass/family_group.list", sep=" ",names = ['group'],index_col=0)

# %%
group
# Out:
#         group
# 183710   bact
# 255527   bact
# 1268     bact
# 558314   bact
# 292628   bact
# 84997    bact
# 117942   bact
# 84994    bact
# 641876   bact
# 90627    bact
# 1471398  bact
# 89373    bact
# 82115    bact
# 32033    bact
# 2092     bact
# 1300     bact
# 219687   bact
# 1328881  bact
# 539003   bact
# 563798   bact
# 1221     bact
# 1334117  bact
# 119045   bact
# 332161   bact
# 224380   bact
# 412447   bact
# 186824   bact
# 85019    bact
# 543      bact
# 69657    bact
# ...       ...
# 1644056  arch
# 90142    arch
# 1033997  arch
# 2236     arch
# 1392996  arch
# 2206     arch
# 196137   arch
# 660062   arch
# 570265   arch
# 2307     arch
# 196117   arch
# 255472   arch
# 46630    arch
# 871007   arch
# 1644061  arch
# 2178     arch
# 685949   arch
# 2267     arch
# 1577788  arch
# 114378   arch
# 1198451  arch
# 2183     arch
# 205957   arch
# 46659    arch
# 2272     arch
# 2232     arch
# 118883   arch
# 2259     arch
# 2194     arch
# 2159     arch
#
# ...

# %%
new_precision = new_family.join(group, on="real_tax_id")

# %%
new_precision
# Out:
#      family_id  precision  family  real_tax_id  group
# 0          0.0   0.000000       0         5809    euk
# 1          1.0   0.435310       1        31469    euk
# 2          2.0   0.700692       2         5654    euk
# 3          3.0   0.000000       3         3216    euk
# 4          4.0   0.000000       4         3401    euk
# 5          5.0   0.000000       5         3440    euk
# 6          6.0   0.750000       6         4405    euk
# 7          7.0   0.000000       7        41773    euk
# 8          8.0   0.272727       8        25664    euk
# 9          9.0   0.500000       9         3298    euk
# 10        10.0   0.666667      10         4410    euk
# 11        11.0   0.368421      11         3362    euk
# 12        12.0   0.000000      12         3394    euk
# 13        13.0   0.307034      13         3367    euk
# 14        14.0   0.000000      14        25623    euk
# 15        15.0   0.263254      15         3700    euk
# ...

# %%
precision_group = new_precision.loc[:,['precision','group']]

# %%
precision_group.groupby(['group']).count()
# Out:
#        precision
# group
# arch          18
# bact         175
# euk          602
# virus         16

# %%
precision_group.hist(column='precision',by='group',bins=20,figsize=(14, 14))
plt.suptitle("precision",fontsize=16)

# %%
recall = pd.read_csv("../../Pipeline/MultiClass/Family/recall_by_label.txt",sep=" = ",names=['family_id','recall'])
new_family_recall = recall.join(family)
new_recall = new_family_recall.join(group, on="real_tax_id")
recall_group = new_recall.loc[:,['recall','group']]
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
recall_group.hist(column='recall',by='group',bins=20,figsize=(14, 14))
plt.suptitle("recall",fontsize=16)

# %%
f1 = pd.read_csv("../../Pipeline/MultiClass/Family/f1_by_label.txt",sep=" = ",names=['family_id','f1'])
new_family_f1 = f1.join(family)
new_f1 = new_family_f1.join(group, on="real_tax_id")
f1_group = new_f1.loc[:,['f1','group']]
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
f1_group.hist(column='f1',by='group',bins=20,figsize=(14, 14))
plt.suptitle("f1",fontsize=16)
