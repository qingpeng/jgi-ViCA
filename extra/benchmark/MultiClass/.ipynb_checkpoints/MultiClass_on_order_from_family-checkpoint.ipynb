# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
matrix = pd.read_csv('../../Pipeline/MultiClass/Family_on_order/matrix.txt',sep = '\s+',header=None)

# %%
df2 = matrix.div(matrix.sum(axis=1),axis=0)

# %%
fig, ax = plt.subplots(figsize= (18,16))
sns.heatmap(df2,xticklabels=False,yticklabels=False)
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
precision = pd.read_csv("../../Pipeline/MultiClass/Family_on_order/precision_by_label.txt",sep=" = ",names=['real_tax_id','precision'])
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
group = pd.read_csv("../../Pipeline/MultiClass/order_group.list", sep=" ",names = ['group'],index_col=0)

# %%
new_precision = precision.join(group, on="real_tax_id")

# %%
precision_group = new_precision.loc[:,['precision','group']]

# %%
precision_group.groupby(['group']).count()
# Out:
#        precision
# group
# arch          15
# bact          85
# euk          261
# virus          7

# %%
precision_group.groupby(['group']).describe()
# Out:
#               precision
# group
# arch  count   15.000000
#       mean     0.494332
#       std      0.272040
#       min      0.097775
#       25%      0.309209
#       50%      0.480519
#       75%      0.694427
#       max      0.957282
# bact  count   85.000000
#       mean     0.328937
#       std      0.305376
#       min      0.000000
#       25%      0.060924
#       50%      0.199497
#       75%      0.562586
#       max      0.994907
# euk   count  261.000000
#       mean     0.344016
#       std      0.341405
#       min      0.000000
#       25%      0.000000
#       50%      0.253369
#       75%      0.619048
#       max      1.000000
# virus count    7.000000
#       mean     0.809171
#       std      0.246770
#       min      0.338173
#       25%      0.714179
#       50%      0.932692
#       75%      0.983362
#       max      0.998246

# %%
precision_group.hist(column='precision',by='group',bins=20,figsize=(10, 10))
plt.suptitle("precision",fontsize=16)

# %%
recall = pd.read_csv("../../Pipeline/MultiClass/Family_on_order/recall_by_label.txt",sep=" = ",names=['real_tax_id','recall'])

new_recall = recall.join(group, on="real_tax_id")

recall_group = new_recall.loc[:,['recall','group']]
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
recall_group.hist(column='recall',by='group',bins=20,figsize=(10, 10))
plt.suptitle("recall",fontsize=16)

# %%
f1 = pd.read_csv("../../Pipeline/MultiClass/Family_on_order/f1_by_label.txt",sep=" = ",names=['real_tax_id','f1'])
new_f1 = f1.join(group, on="real_tax_id")

f1_group = new_f1.loc[:,['f1','group']]
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
f1_group.hist(column='f1',by='group',bins=20,figsize=(10, 10))
plt.suptitle("f1",fontsize=16)
