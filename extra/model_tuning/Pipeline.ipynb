# %% [markdown]
# ## Training Model using Developer datasets
#
# Using scikit-learn...
#
# with Pfam, sparse... no median
#
# without Pfam, sparse... scaler to median ,to  see difference...

# %% [markdown]
# training with scaler
#
# ```
# python ~/Dropbox/Development/Github/jgi-ViCA/scripts/sklearn_training_model.py training.vect training.vect.sklearn_model training.vect.sklearn_scaler False
#   529  python ~/Dropbox/Development/Github/jgi-ViCA/scripts/sklearn_training_model.py training.vect.0_1 training.vect.0_1.sklearn_model training.vect.0_1_sklearn_scaler False
# ```
# evaluating model with scaler
#
# ```
# python ~/Dropbox/Development/Github/jgi-ViCA/scripts/sklearn_evaluate_model.py testing.vect training.vect.sklearn_model training.vect.sklearn_scaler training.vect.sklearn_model.report
# python ~/Dropbox/Development/Github/jgi-ViCA/scripts/sklearn_evaluate_model.py testing.vect.0_1 training.vect.0_1.sklearn_model training.vect.0_1_sklearn_scaler training.vect.0_1.sklearn_model.report
#
# ## training.vect.sklearn_model.report
# auprc=0.948489439379
# confusion_matrix:
# 4574 426
# 365 4635
#
# ## training.vect.0_1.sklearn_model.report
# auprc=0.933905078086
# confusion_matrix:
# 4416 584
# 775 4225
# ```
#
# For without_pfam data, can scaled into median=0
#
# ```
# python ~/Dropbox/Development/Github/jgi-ViCA/scripts/sklearn_training_model.py training.vect.0_1 training.vect.0_1.sklearn_model_median_True training.vect.0_1_sklearn_scaler_median_True True
#
# python ~/Dropbox/Development/Github/jgi-ViCA/scripts/sklearn_evaluate_model.py testing.vect.0_1 training.vect.0_1.sklearn_model_median_True training.vect.0_1_sklearn_scaler_median_True True training.vect.0_1.sklearn_model_median_True.report
#
#
# ## training.vect.0_1.sklearn_model_median_True.report
# auprc=0.920713380173
# confusion_matrix:
# 4296 704
# 873 4127
#
# ```

# %% [markdown]
# ## Training model using all datasets
#
# ### Purpose
# - generate model to ship with package
# - decide if we want to keep pfam/vfam features
#
# Now the problem is:
# using all datasets, without Pfam feature, the performance is bad...
# from sklearn
#
# Also, how to deal with imbalanced data of the full datasets.
#
# scaler... + scaler to mean for no-pfam data!

# %% [markdown]
# ### tried Spark Mllib
#
# Couldn't finish due to memory usage issue.
#
# Tried StandardScaler, does not improve.

# %% [markdown]
# ### Tried Scikit-learn
#
# without standardscaler...

# %% [markdown]
# ```
# scikit_without_pfam.qsub
# scikit_without_pfam_debug.qsub
# ```
#
# previously, all use standardscaler.. try this using scikit learn.
#
# Then to see the performance
#
# and compare the parameters between MLlib and scikit learn
#
#
# #### with "weight" option off
#
# ```
#   852  python ~/Github/jgi-ViCA/scripts/sklearn_evaluate_model.py ../../testing.vect.0_1 all_segment.fasta.vect.family.training.svmlib.no4.0_1_scikit_model all_segment.fasta.vect.family.training.svmlib.no4.0_1_scikit_model.evaluation_report
#   853  python ~/Github/jgi-ViCA/scripts/sklearn_evaluate_model.py ../../testing.vect all_segment.fasta.vect.family.training.svmlib.no4_scikit_model all_segment.fasta.vect.family.training.svmlib.no4_scikit_model_evaluate_report
#   ```
#
# With Pfam:
# ```
# auprc=0.927696899665
# confusion_matrix:
# 4983 17
# 3280 1720
# ```
#
# Without Pfam:
# ```
# auprc=0.50460773337
# confusion_matrix:
# 5000 0
# 5000 0
# ```
#
#
# #### with "weight" option on
# With Pfam:
# ```
# auprc=0.936991747843
# confusion_matrix:
# 3850 1150
# 561 4439
# ```
#
# Without Pfam:
# ```
# auprc=0.578419200156
# confusion_matrix:
# 2167 2833
# 2317 2683
# ```

# %% [markdown]
# ## Try scikit learn using StandardScaler, as Spark, to compare

# %% [markdown]
# for no pfam data, scaler to median as 0
#
# ```
# qpzhang@genepool14:/global/projectb/scratch/qpzhang/Run_Genelearn/Full_nextflow/Test_Spark/
#
# qsub sklearn_without_pfam_scaler_median_True.qsub
# Your job 32765221 ("sklearn_without_pfam_scaler_median_True.qsub") has been submitted
#
# ```

# %% [markdown]
# ## Full dataset, with 1x, 2x, 3x non-virus segments, using subsampling

# %% [markdown]
# ```
# python ~/Github/jgi-ViCA/scripts/subsample_random.py all_segment.fasta.vect.family.training.svmlib.no4.0_1 &
#
#
# qpzhang@genepool14:/global/projectb/scratch/qpzhang/Run_Genelearn/Full_nextflow/Test_Spark$ qsub sklearn_without_pfam_scaler_median_True_1x.qsub
# Your job 32767209 ("sklearn_without_pfam_scaler_median_True_1x.qsub") has been submitted
# qpzhang@genepool14:/global/projectb/scratch/qpzhang/Run_Genelearn/Full_nextflow/Test_Spark$ qsub sklearn_without_pfam_scaler_median_True_2x.qsub
# Your job 32767238 ("sklearn_without_pfam_scaler_median_True_2x.qsub") has been submitted
# qpzhang@genepool14:/global/projectb/scratch/qpzhang/Run_Genelearn/Full_nextflow/Test_Spark$ qsub sklearn_without_pfam_scaler_median_True_3x.qsub
# Your job 32767264 ("sklearn_without_pfam_scaler_median_True_3x.qsub") has been submitted
#
# /global/projectb/scratch/qpzhang/Run_Genelearn/Full_nextflow/Test_Spark
#
#
# 1x
#
#
# python ~/Github/jgi-ViCA/scripts/sklearn_evaluate_model.py ../testing.vect.0_1  all_segment.fasta.vect.family.training.svmlib.no4.0_1_scikit_model_median_True_1x all_segment.fasta.vect.family.training.svmlib.no4.0_1_scikit_scaler_median_True_1x True all_segment.fasta.vect.family.training.svmlib.no4.0_1_scikit_model_median_True_1x.report
#
# auprc=0.948862709111
# confusion_matrix:
# 4400 600
# 540 4460
# precision recall thresholds
#
#
# 2x
#
#
# python ~/Github/jgi-ViCA/scripts/sklearn_evaluate_model.py ../testing.vect.0_1  all_segment.fasta.vect.family.training.svmlib.no4.0_1_scikit_model_median_True_2x all_segment.fasta.vect.family.training.svmlib.no4.0_1_scikit_scaler_median_True_2x True all_segment.fasta.vect.family.training.svmlib.no4.0_1_scikit_model_median_True_2x.report &
#
# auprc=0.95072404265
# confusion_matrix:
# 4698 302
# 986 4014
# precision recall thresholds
#
#
# python ~/Github/jgi-ViCA/scripts/sklearn_evaluate_model.py ../testing.vect.0_1  all_segment.fasta.vect.family.training.svmlib.no4.0_1_scikit_model_median_True_3x all_segment.fasta.vect.family.training.svmlib.no4.0_1_scikit_scaler_median_True_3x True all_segment.fasta.vect.family.training.svmlib.no4.0_1_scikit_model_median_True_3x.report &
#
#
# auprc=0.951285366838
# confusion_matrix:
# 4800 200
# 1343 3657
# precision recall thresholds
#
#
# ```

# %% [markdown]
# ## Add New features and test on developer data

# %% [markdown]
# ```
# python ../scripts/2_feature_genemark.py --input test-data/test_segment_5k.fa.3 --output_prefix test_segment_5k.fa.3 --genemark_path ~/bin/genemark_suite_macosx/gmsuite/
# ```
#
# test 5k 5k fasta
#
# /Users/qingpeng/Local/GeneLearn/NewFeature
#
# ```
# python ~/Dropbox/Development/Github/jgi-ViCA/scripts/2_feature_genemark.py --input testing_5k.vect.fasta --output_prefix testing_5k.vect.fasta --genemark_path ~/bin/genemark_suite_macosx/gmsuite/
# python ~/Dropbox/Development/Github/jgi-ViCA/scripts/3_feature_kmer.py --input testing_5k.vect.fasta --output testing_5k.vect.fasta.kmer
#
#
# python ~/Dropbox/Development/Github/jgi-ViCA/scripts/4_feature_combine.py --output testing_5k.vect.fasta.vector testing_5k.vect.fasta.kmer testing_5k.vect.fasta.genemark
#
#
#  python ~/Dropbox/Development/Github/jgi-ViCA/scripts/prepare_libsvm_for_prediction.py testing_5k.vect.fasta.vector ~/Dropbox/Development/Github/jgi-ViCA/scripts/all_segment.fasta.vect.feature_index.nopfam testing_5k.vect.fasta.vector.libsvm
#
#
# ```
# training 25k 25k on genepool
#
# using nextflow to run
#
# ```
# /global/projectb/scratch/qpzhang/Run_Genelearn/Full_nextflow/Split_with_name/
#
# nextflow run training.nf
#
#   628  python ~/Github/jgi-ViCA/scripts/3_feature_kmer.py  --input training_25k.vect.fasta --output training_25k.vect.fasta.kmer
#
# python ~/Github/jgi-ViCA/scripts/4_feature_combine.py --output training_25k.vect.fasta.vector training_25k.vect.fasta.kmer training_25k.vect.fasta.genemark_feature
#
# head -392 all_segment.fasta.vect.feature_index  >all_segment.fasta.vect.feature_index.nopfam
#
# qpzhang@genepool14:/global/projectb/scratch/qpzhang/Run_Genelearn/Full_nextflow/Split_with_name$ tail all_segment.fasta.vect.feature_index.nopfam
# 386 1_94
# 387 1_95
# 388 1_96
# 389 1_97
# 390 1_98
# 391 1_99
# 392 1_fraction_coding
# 393 1_ave_gene_length
# 394 1_ave_intergenic_length
#
# python ~/Github/jgi-ViCA/scripts/prepare_libsvm_for_prediction.py training_25k.vect.fasta.vector all_segment.fasta.vect.feature_index.nopfam training_25k.vect.fasta.vector.libsvm
#
# modify class according to older labels...
# for training...
# should specify class label
#
# python ~/Github/jgi-ViCA/scripts/modify_class_for_training.py training_25k.vect training_25k.vect.fasta.vector.libsvm training_25k.vect.fasta.vector.libsvm.modify
#
#
# python ~/Github/jgi-ViCA/scripts/modify_class_for_training.py testing_5k.vect testing_5k.vect.fasta.vector.libsvm testing_5k.vect.fasta.vector.libsvm.modify
#  1745  python ~/Github/jgi-ViCA/scripts/sklearn_evaluate_model.py
#  1746  python ~/Github/jgi-ViCA/scripts/sklearn_evaluate_model.py testing_5k.vect.fasta.vector.libsvm.modify training_25k.vect.fasta.vector.libsvm.modify.model training_25k.vect.fasta.vector.libsvm.modify.scaler True training_25k.vect.fasta.vector.libsvm.modify.model.report
#  1747  more training_25k.vect.fasta.vector.libsvm.modify.model.report
#
#  auprc=0.82426738243
# confusion_matrix:
# 3924 1076
# 1608 3392
# precision recall thresholds
#
# ```
